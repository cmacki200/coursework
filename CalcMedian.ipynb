# %%
import numpy as np

while True:
    x = input("please enter several numbers seperated by a space ")
    try:
        y = x.replace(" ","")
        print(x)
        y = int(y)
    except:
        print('Please use numeric digits.')
        continue
    break

strArr = x.split()
map_input = map(int, strArr)
user_input = list(map_input)

l = len(user_input)
# user_input.sort()
#no longer needed due to map

if l % 2 == 0:
  median1 = user_input[l//2]
  median2 = user_input[l//2-1]
  median = (median1 + median2)/2
  print("the length of the set of numbers is even")
  print(median)
else:
  print("the length of the set of numbers is odd")
  median = user_input[l//2]
  print("the median is " + median)
