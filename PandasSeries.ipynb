# %%
import pandas as pd
import numpy as np

ran = np.random.RandomState(10)

p = pd.Series(np.random.randint(0,10,4))
p

pFrame = pd.DataFrame(ran.randint(0,10,(3,4)),columns=['A','B','C','D'])

np.exp(p)

calc = np.sin(pFrame * np.pi / 4)
calc

# area = pd.Series({"Alaska": 177890, "Georgia": 123786, "Washington": 678997}, name= "area")
# areaTest = pd.Series({"data goes here": 123, "more data":456,"end of data":789}, name="test")
# area

area = pd.Series({'Alaska': 1723337, 'Texas': 695662,
                  'California': 423967}, name='area')
population = pd.Series({'California': 38332521, 'Texas': 26448193,
                        'New York': 19651127}, name='population')

population / area

area.index | population.index

A = pd.Series([2, 4, 6], index=[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])
A + B #will provide NaN val
A.add(B,fill_value=0)#will fill NaN val using data given

A = pd.DataFrame(ran.randint(0, 20, (2, 2)),
                 columns=list('AB'))
# print(A)

B = pd.DataFrame(ran.randint(0, 10, (3, 3)),
                 columns=list('BAC'))
# print('\n', B)
