# %%
from google.colab import drive
import pandas as pd
import numpy as np

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls '/content/drive/My Drive/MscBigData/SDForDataScience/balance.csv'

fPath = '/content/drive/My Drive/MscBigData/SDForDataScience/balance.csv'
data = pd.read_csv(fPath)

cols = data.columns.to_list()
display(cols)
print("")
x = (data["Institutional_sector_code"].tolist())
arr = np.array(x)
narray = arr.reshape(10, 1872)
print(narray)
# print(arr)
# print(np.shape(narray))
print(np.sum((narray > 150 ) & (narray < 300)))
# print(len(arr))
# Out:
# '/content/drive/My Drive/MscBigData/SDForDataScience/balance.csv'
# ['Year',
#  'Institutional_sector_name',
#  'Institutional_sector_code',
#  'Descriptor',
#  'SNA08TRANS',
#  'Asset_liability_code',
#  'Status',
#  'Values']
# [[141 141 141 ...  27  27  27]
#  [ 27  27  27 ... 311 311 311]
#  [311 311 311 ... 321 321 321]
#  ...
#  [221 221 221 ... 231 231 231]
#  [231 231 231 ... 251 251 251]
#  [251 251 251 ... 261 261 261]]
# 8320

# %%
z = np.random.randint(0, 10, 50)
(z + 2) == (z ** 2)

rng = np.random.RandomState(0)
arrBool = rng.randint(10, size = [3,4])
print(arrBool)
np.count_nonzero(arrBool >= 4)

np.all(arrBool ==9, axis=0)

# %%
A = np.array([1, 0, 1, 0, 1, 0], dtype=bool)
B = np.array([1, 1, 0, 0, 1, 1], dtype=bool)
C = np.array([0, 0, 0, 0, 1, 1], dtype=bool)
B | A | C
# Out:
# array([ True,  True,  True, False,  True,  True])

# %%
x = np.random.randint(100, size=10)
print(x)

try:
    val1=int(input("Type a number: "))
    val2=int(input("Type a number: "))
    val3=int(input("Type a number: "))
except ValueError:
    print("This is not a whole number.")


ind= [val1,val2,val3]

x[ind]

# %%
X = np.arange(12).reshape((3, 4))

row = np.array([0, 1, 2])
col = np.array([2, 1, 3])
print(X)
print("")
print(X[1:])
print("")
print(X[1:, [2, 0, 1]])
print("")
mask = np.array([1, 0, 1, 0], dtype=bool)
print(X[row[:, np.newaxis], mask])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-960e9d003e22> in <module>()
# ----> 1 X = np.arange(12).reshape((3, 4))
#       2
#       3 row = np.array([0, 1, 2])
#       4 col = np.array([2, 1, 3])
#       5 print(X)
#
# NameError: name 'np' is not defined

# %%
mean = [0, 0]
cov = [[1, 2],
       [2, 5]]
X = np.random.multivariate_normal(mean, cov, 100)
X.shape

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # for plot styling

indices = np.random.choice(X.shape[0], 20, replace=False)
indices

selection = X[indices]  # fancy indexing here
selection.shape

plt.scatter(X[:, 0], X[:, 1], alpha=0.3)
plt.scatter(selection[:, 0], selection[:, 1],
            facecolor='none', s=200);

# %%
x = np.zeros(10)
x[[0, 0]] = [4, 6]
print(x)

i = [2, 3, 3, 4, 4, 4]
x[i] += 1
print(i)
x

np.add.at(x, i, 1)
print(x)
# Out:
# [6. 0. 0. 0. 0. 0. 0. 0. 0. 0.]
# [2, 3, 3, 4, 4, 4]
# [6. 0. 2. 3. 4. 0. 0. 0. 0. 0.]
